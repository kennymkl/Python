# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import os
import time

def scrape_month_year_links(base_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(base_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find(id="container_date")
    links = []

    if container:
        for a in container.find_all('a', href=True):
            if 'docmonth' in a['href']:
                links.append(a['href'])
    return links

def scrape_document_links(doc_page_url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(doc_page_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find(id="container_title")
    links = []

    if container:
        for li in container.find_all('li'):
            a = li.find('a', href=True)
            if a:
                links.append(a['href'])
    return links

def scrape_and_save(url, output_folder):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'}
    retries = 3
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 200:
                break
            else:
                time.sleep(5 ** attempt)  # Exponential backoff
        except requests.exceptions.RequestException:
            if attempt < retries - 1:  # i.e., not last attempt
                time.sleep(5 ** attempt)
                continue
            else:
                print("Failed to retrieve the webpage after multiple attempts")
                return

    soup = BeautifulSoup(response.text, 'html.parser')
    data = {"title": "", "text": "", "approval_date": "", "url": url}

    title_element = soup.find('h2')
    if title_element:
        cleaned_title = re.sub(r"[\[\]]", "", title_element.text).strip()
        data["title"] = cleaned_title
        filename = re.sub(r'[\/:*?"<>|]', '', cleaned_title) + '.json'

    full_text_div = soup.find('div', {'align': 'JUSTIFY'})
    if full_text_div:
        for sup in full_text_div.find_all('sup'):
            sup.decompose()
        # Extract text separated by <br> tags
        text_parts = [part.strip() for part in full_text_div.get_text(separator="\n", strip=True).split("\n") if part.strip()]
        data["text"] = "\n\n".join(text_parts)

    approval_date_match = re.search(r"Approved, ([\w\s,]+)\.", data["text"])
    if approval_date_match:
        data["approval_date"] = approval_date_match.group(1)

    with open(os.path.join(output_folder, filename), 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, indent=4, ensure_ascii=False)
    print(f"Data has been saved to {filename}")

def main():
    base_url = "https://elibrary.judiciary.gov.ph/thebookshelf/28"
    output_folder = 'Acts'
    os.makedirs(output_folder, exist_ok=True)

    month_year_links = scrape_month_year_links(base_url)
    for link in month_year_links:
        full_url = 'https://elibrary.judiciary.gov.ph' + link if not link.startswith('http') else link
        document_links = scrape_document_links(full_url)
        for doc_link in document_links:
            full_doc_url = 'https://elibrary.judiciary.gov.ph' + doc_link if not doc_link.startswith('http') else doc_link
            scrape_and_save(full_doc_url, output_folder)
#             time.sleep(5)  # Sleep for 5 seconds after each document scrape to avoid overwhelming the server

if __name__ == "__main__":
    main()
# Out:
# Data has been saved to BATAS PAMBANSA BLG. 866, January 31, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 868, February 20, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 869, April 18, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 870, April 18, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 871, May 29, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 873, June 12, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 874, June 12, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 875, June 12, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 876, June 12, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 877, June 12, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 872, June 10, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 878, July 09, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 879, October 22, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 880, October 22, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 882, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 887, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 888, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 883, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 884, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 885, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 886, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 889, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 881, December 03, 1985.json
# Data has been saved to BATAS PAMBANSA BLG. 644, January 05, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 697, March 14, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 698, March 14, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 695, March 09, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 696, March 09, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 689, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 645, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 646, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 647, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 648, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 649, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 650, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 651, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 652, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 653, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 654, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 655, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 656, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 657, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 658, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 659, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 660, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 662, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 663, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 664, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 665, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 666, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 661, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 667, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 668, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 669, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 670, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 671, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 672, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 673, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 674, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 675, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 677, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 678, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 676, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 679, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 680, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 681, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 682, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 683, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 684, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 685, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 686, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 687, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 688, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 690, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 691, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 693, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 692, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 694, March 07, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 784, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 783, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 785, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 786, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 787, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 788, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 789, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 790, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 791, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 792, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 793, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 794, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 795, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 796, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 797, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 798, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 799, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 800, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 801, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 802, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 803, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 804, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 805, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 806, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 807, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 808, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 809, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 810, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 815, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 811, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 813, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 812, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 814, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 816, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 817, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 818, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 819, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 820, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 822, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 823, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 824, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 825, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 826, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 827, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 828, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 829, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 830, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 831, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 832, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 833, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 834, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 835, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 836, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 837, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 838, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 839, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 840, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 841, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 842, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 843, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 844, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 845, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 846, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 847, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 848, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 849, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 850, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 851, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 852, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 853, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 854, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 855, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 856, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 857, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 858, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 859, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 860, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 861, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 862, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 863, April 27, 1984.json
# Data has been saved to BATAS PAMBANSA BLG. 864, April 27, 1984.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 93
#      90 #             time.sleep(5)  # Sleep for 5 seconds after each document scrape to avoid overwhelming the server
#      92 if __name__ == "__main__":
# ---> 93     main()
#
# Cell In[1], line 89, in main()
#      87 for doc_link in document_links:
#      88     full_doc_url = 'https://elibrary.judiciary.gov.ph' + doc_link if not doc_link.startswith('http') else doc_link
# ---> 89     scrape_and_save(full_doc_url, output_folder)
#
# Cell In[1], line 40, in scrape_and_save(url, output_folder)
#      38 for attempt in range(retries):
#      39     try:
# ---> 40         response = requests.get(url, headers=headers)
#      41         if response.status_code == 200:
#      42             break
#
# File D:\Python\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File D:\Python\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File D:\Python\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File D:\Python\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File D:\Python\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File D:\Python\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File D:\Python\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File D:\Python\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File D:\Python\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File D:\Python\lib\http\client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File D:\Python\lib\http\client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File D:\Python\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File D:\Python\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File D:\Python\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
