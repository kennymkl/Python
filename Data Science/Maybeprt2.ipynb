# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import os
import time

def scrape_month_year_links(base_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(base_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find(id="container_date")
    links = []

    if container:
        for a in container.find_all('a', href=True):
            if 'docmonth' in a['href']:
                links.append(a['href'])
    return links

def scrape_document_links(doc_page_url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(doc_page_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find(id="container_title")
    links = []

    if container:
        for li in container.find_all('li'):
            a = li.find('a', href=True)
            if a:
                links.append(a['href'])
    return links

def scrape_and_save(url, output_folder):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'}
    retries = 3
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 200:
                break
            else:
                time.sleep(5 ** attempt)  # Exponential backoff
        except requests.exceptions.RequestException:
            if attempt < retries - 1:  # i.e., not last attempt
                time.sleep(5 ** attempt)
                continue
            else:
                print("Failed to retrieve the webpage after multiple attempts")
                return

    soup = BeautifulSoup(response.text, 'html.parser')
    data = {"title": "", "text": "", "approval_date": "", "url": url}

    title_element = soup.find('h2')
    if title_element:
        cleaned_title = re.sub(r"[\[\]]", "", title_element.text).strip()
        data["title"] = cleaned_title
        filename = re.sub(r'[\/:*?"<>|]', '', cleaned_title) + '.json'

    # Find the div after the H3 tag
    div_elements = soup.find_all('div', {'align': 'justify'})
    text_parts = []
    for div in div_elements:
        # Clean up and decompose <sup> tags which are usually references or footnotes
        for sup in div.find_all('sup'):
            sup.decompose()
        text_parts.append(div.get_text(separator="\n", strip=True))

    data["text"] = "\n\n".join(text_parts)

    approval_date_match = re.search(r"Approved, ([\w\s,]+)\.", data["text"])
    if approval_date_match:
        data["approval_date"] = approval_date_match.group(1)

    with open(os.path.join(output_folder, filename), 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, indent=4, ensure_ascii=False)
    print(f"Data has been saved to {filename}")


def main():
    base_url = "https://elibrary.judiciary.gov.ph/thebookshelf/28"
    output_folder = 'Republic Acts'
    os.makedirs(output_folder, exist_ok=True)

    month_year_links = scrape_month_year_links(base_url)
    for link in month_year_links:
        full_url = 'https://elibrary.judiciary.gov.ph' + link if not link.startswith('http') else link
        document_links = scrape_document_links(full_url)
        for doc_link in document_links:
            full_doc_url = 'https://elibrary.judiciary.gov.ph' + doc_link if not doc_link.startswith('http') else doc_link
            scrape_and_save(full_doc_url, output_folder)
#             time.sleep(5)  # Sleep for 5 seconds after each document scrape to avoid overwhelming the server

if __name__ == "__main__":
    main()
# Out:
# Data has been saved to Acts No. 4197, February 12, 1935.json
# Data has been saved to Acts No. 4196, February 05, 1935.json
# Data has been saved to Acts No. 4195, February 01, 1935.json
# Data has been saved to Acts No. 4199, March 16, 1935.json
# Data has been saved to Acts No. 4198, March 04, 1935.json
# Data has been saved to Acts No. 4200, April 08, 1935.json
# Data has been saved to Acts No. 4202, June 20, 1935.json
# Data has been saved to Acts No. 4201, June 13, 1935.json
# Data has been saved to Acts No. 4206, July 30, 1935.json
# Data has been saved to Acts No. 4205, July 25, 1935.json
# Data has been saved to Acts No. 4204, July 23, 1935.json
# Data has been saved to Acts No. 4203, July 23, 1935.json
# Data has been saved to Acts No. 4242, August 26, 1935.json
# Data has been saved to Act No. 4241, August 23, 1935.json
# Data has been saved to Acts No. 4240, August 22, 1935.json
# Data has been saved to Acts No. 4239, August 22, 1935.json
# Data has been saved to Acts No. 4238, August 21, 1935.json
# Data has been saved to Acts No. 4235, August 20, 1935.json
# Data has been saved to Acts No. 4236, August 20, 1935.json
# Data has been saved to Acts No. 4237, August 20, 1935.json
# Data has been saved to Acts No. 4232, August 16, 1935.json
# Data has been saved to Acts No. 4233, August 16, 1935.json
# Data has been saved to Acts No. 4234, August 16, 1935.json
# Data has been saved to Acts No. 4231, August 16, 1935.json
# Data has been saved to Acts No. 4230, August 16, 1935.json
# Data has been saved to Acts No. 4229, August 12, 1935.json
# Data has been saved to Acts No. 4228, August 10, 1935.json
# Data has been saved to Acts No. 4227, August 09, 1935.json
# Data has been saved to Acts No. 4226, August 09, 1935.json
# Data has been saved to Acts No. 4225, August 08, 1935.json
# Data has been saved to Acts No. 4221, August 07, 1935.json
# Data has been saved to Acts No. 4224, August 07, 1935.json
# Data has been saved to Acts No. 4222, August 07, 1935.json
# Data has been saved to Acts No. 4223, August 07, 1935.json
# Data has been saved to Acts No. 4219, August 06, 1935.json
# Data has been saved to Acts No. 4220, August 06, 1935.json
# Data has been saved to Acts No. 4218, August 06, 1935.json
# Data has been saved to Acts No. 4217, August 06, 1935.json
# Data has been saved to Acts No. 4216, August 05, 1935.json
# Data has been saved to Acts No. 4214, August 05, 1935.json
# Data has been saved to Acts No. 4215, August 05, 1935.json
# Data has been saved to Acts No. 4213, August 03, 1935.json
# Data has been saved to Acts No. 4210, August 02, 1935.json
# Data has been saved to Acts No. 4211, August 02, 1935.json
# Data has been saved to Acts No. 4212, August 02, 1935.json
# Data has been saved to Acts No. 4209, August 01, 1935.json
# Data has been saved to Acts No. 4207, August 01, 1935.json
# Data has been saved to Acts No. 4208, August 01, 1935.json
# Data has been saved to Acts No. 4243, September 21, 1935.json
# Data has been saved to Acts No. 4248, October 31, 1935.json
# Data has been saved to Acts No. 4246, October 28, 1935.json
# Data has been saved to Acts No. 4247, October 28, 1935.json
# Data has been saved to Acts No. 4245, October 14, 1935.json
# Data has been saved to Acts No. 4244, October 10, 1935.json
# Data has been saved to Acts No. 4272, November 14, 1935.json
# Data has been saved to Acts No. 4274, November 14, 1935.json
# Data has been saved to Acts No. 4275, November 14, 1935.json
# Data has been saved to Acts No. 4273, November 14, 1935.json
# Data has been saved to Acts No. 4271, November 14, 1935.json
# Data has been saved to Acts No. 4270, November 14, 1935.json
# Data has been saved to Acts No. 4269, November 08, 1935.json
# Data has been saved to Acts No. 4268, November 08, 1935.json
# Data has been saved to Acts No. 4267, November 07, 1935.json
# Data has been saved to Acts No. 4266, November 07, 1935.json
# Data has been saved to Acts No. 4262, November 07, 1935.json
# Data has been saved to Acts No. 4263, November 07, 1935.json
# Data has been saved to Acts No. 4264, November 07, 1935.json
# Data has been saved to Acts No. 4265, November 07, 1935.json
# Data has been saved to Acts No. 4261, November 07, 1935.json
# Data has been saved to Acts No. 4259, November 06, 1935.json
# Data has been saved to Acts No. 4260, November 06, 1935.json
# Data has been saved to Acts No. 4256, November 06, 1935.json
# Data has been saved to Acts No. 4257, November 06, 1935.json
# Data has been saved to Acts No. 4258, November 06, 1935.json
# Data has been saved to Acts No. 4249, November 06, 1935.json
# Data has been saved to Acts No. 4250, November 06, 1935.json
# Data has been saved to Acts No. 4251, November 06, 1935.json
# Data has been saved to Acts No. 4252, November 06, 1935.json
# Data has been saved to Acts No. 4253, November 06, 1935.json
# Data has been saved to Acts No. 4254, November 06, 1935.json
# Data has been saved to Acts No. 4255, November 06, 1935.json
# Data has been saved to Acts No. 4124, February 09, 1934.json
# Data has been saved to Acts No. 4126, May 26, 1934.json
# Data has been saved to Acts No. 4125, May 26, 1934.json
# Data has been saved to Acts No. 4127, August 21, 1934.json
# Data has been saved to Acts No. 4130, October 30, 1934.json
# Data has been saved to Acts No. 4129, October 09, 1934.json
# Data has been saved to Acts No. 4128, October 05, 1934.json
# Data has been saved to Acts No. 4152, November 28, 1934.json
# Data has been saved to Acts No. 4153, November 28, 1934.json
# Data has been saved to Acts No. 4151, November 28, 1934.json
# Data has been saved to Acts No. 4147, November 28, 1934.json
# Data has been saved to Acts No. 4148, November 28, 1934.json
# Data has been saved to Acts No. 4149, November 28, 1934.json
# Data has been saved to Acts No. 4150, November 28, 1934.json
# Data has been saved to Acts No. 4144, November 26, 1934.json
# Data has been saved to Acts No. 4145, November 26, 1934.json
# Data has been saved to Acts No. 4146, November 26, 1934.json
# Data has been saved to Acts No. 4143, November 26, 1934.json
# Data has been saved to Acts No. 4141, November 24, 1934.json
# Data has been saved to Acts No. 4142, November 24, 1934.json
# Data has been saved to Acts No. 4140, November 24, 1934.json
# Data has been saved to Acts No. 4138, November 23, 1934.json
# Data has been saved to Acts No. 4139, November 23, 1934.json
# Data has been saved to Acts No. 4134, November 22, 1934.json
# Data has been saved to Acts No. 4135, November 22, 1934.json
# Data has been saved to Acts No. 4137, November 22, 1934.json
# Data has been saved to Acts No. 4136, November 22, 1934.json
# Data has been saved to Acts No. 4133, November 22, 1934.json
# Data has been saved to Acts No. 4131, November 22, 1934.json
# Data has been saved to Acts No. 4132, November 22, 1934.json
# Data has been saved to Acts No. 4192, December 08, 1934.json
# Data has been saved to Acts No. 4193, December 08, 1934.json
# Data has been saved to Acts No. 4194, December 08, 1934.json
# Data has been saved to Acts No. 4189, December 08, 1934.json
# Data has been saved to Acts No. 4190, December 08, 1934.json
# Data has been saved to Acts No. 4191, December 08, 1934.json
# Data has been saved to Acts No. 4188, December 08, 1934.json
# Data has been saved to Acts No. 4186, December 08, 1934.json
# Data has been saved to Act No. 4187, December 08, 1934.json
# Data has been saved to Acts No. 4181, December 07, 1934.json
# Data has been saved to Acts No. 4182, December 07, 1934.json
# Data has been saved to Acts No. 4183, December 07, 1934.json
# Data has been saved to Acts No. 4184, December 07, 1934.json
# Data has been saved to Acts No. 4185, December 07, 1934.json
# Data has been saved to Acts No. 4179, December 06, 1934.json
# Data has been saved to Act No. 4180, December 06, 1934.json
# Data has been saved to Acts No. 4177, December 05, 1934.json
# Data has been saved to Acts No. 4178, December 05, 1934.json
# Data has been saved to Acts No. 4176, December 05, 1934.json
# Data has been saved to Acts No. 4175, December 05, 1934.json
# Data has been saved to Acts No. 4166, December 04, 1934.json
# Data has been saved to Acts No. 4173, December 04, 1934.json
# Data has been saved to Acts No. 4171, December 04, 1934.json
# Data has been saved to Acts No. 4172, December 04, 1934.json
# Data has been saved to Acts No. 4174, December 04, 1934.json
# Data has been saved to Acts No. 4170, December 03, 1934.json
# Data has been saved to Acts No. 4168, December 03, 1934.json
# Data has been saved to Acts No. 4169, December 03, 1934.json
# Data has been saved to Acts No. 4165, December 03, 1934.json
# Data has been saved to Acts No. 4167, December 03, 1934.json
# Data has been saved to Acts No. 4162, December 01, 1934.json
# Data has been saved to Acts No. 4163, December 01, 1934.json
# Data has been saved to Acts No. 4164, December 01, 1934.json
# Data has been saved to Acts No. 4161, December 01, 1934.json
# Data has been saved to Acts No. 4158, December 01, 1934.json
# Data has been saved to Acts No. 4159, December 01, 1934.json
# Data has been saved to Acts No. 4160, December 01, 1934.json
# Data has been saved to Acts No. 4154, December 01, 1934.json
# Data has been saved to Acts No. 4155, December 01, 1934.json
# Data has been saved to Acts No. 4156, December 01, 1934.json
# Data has been saved to Acts No. 4157, December 01, 1934.json
# Data has been saved to Acts No. 4041, January 21, 1933.json
# Data has been saved to Acts No. 4039, January 06, 1933.json
# Data has been saved to Acts No. 4040, January 06, 1933.json
# Data has been saved to Acts No. 4055, February 27, 1933.json
# Data has been saved to Acts No. 4054, February 27, 1933.json
# Data has been saved to Acts No. 4053, February 24, 1933.json
# Data has been saved to Acts No. 4051, February 21, 1933.json
# Data has been saved to Acts No. 4052, February 21, 1933.json
# Data has been saved to Acts No. 4050, February 20, 1933.json
# Data has been saved to Acts No. 4048, February 18, 1933.json
# Data has been saved to Acts No. 4047, February 18, 1933.json
# Data has been saved to Acts No. 4049, February 18, 1933.json
# Data has been saved to Acts No. 4044, February 18, 1933.json
# Data has been saved to Acts No. 4045, February 18, 1933.json
# Data has been saved to Acts No. 4046, February 18, 1933.json
# Data has been saved to Acts No. 4042, February 10, 1933.json
# Data has been saved to Acts No. 4043, February 10, 1933.json
# Data has been saved to Acts No. 4063, March 01, 1933.json
# Data has been saved to Acts No. 4061, March 01, 1933.json
# Data has been saved to Acts No. 4062, March 01, 1933.json
# Data has been saved to Act No. 4057, March 01, 1933.json
# Data has been saved to Acts No. 4058, March 01, 1933.json
# Data has been saved to Acts No. 4056, March 01, 1933.json
# Data has been saved to Acts No. 4060, March 01, 1933.json
# Data has been saved to Act No. 4059, March 01, 1933.json
# Data has been saved to Acts No. 4064, April 29, 1933.json
# Data has been saved to Acts No. 4066, August 17, 1933.json
# Data has been saved to Acts No. 4065, August 07, 1933.json
# Data has been saved to Acts No. 4068, September 11, 1933.json
# Data has been saved to Acts No. 4067, September 04, 1933.json
# Data has been saved to Acts No. 4077, October 27, 1933.json
# Data has been saved to Acts No. 4076, October 27, 1933.json
# Data has been saved to Acts No. 4075, October 27, 1933.json
# Data has been saved to Act No. 4074, October 19, 1933.json
# Data has been saved to Acts No. 4073, October 12, 1933.json
# Data has been saved to Acts No. 4072, October 12, 1933.json
# Data has been saved to Acts No. 4071, October 12, 1933.json
# Data has been saved to Acts No. 4070, October 12, 1933.json
# Data has been saved to Acts No. 4069, October 10, 1933.json
# Data has been saved to Acts No. 4097, November 29, 1933.json
# Data has been saved to Acts No. 4098, November 29, 1933.json
# Data has been saved to Acts No. 4099, November 29, 1933.json
# Data has been saved to Acts No. 4100, November 29, 1933.json
# Data has been saved to Acts No. 4096, November 29, 1933.json
# Data has been saved to Acts No. 4094, November 29, 1933.json
# Data has been saved to Acts No. 4095, November 29, 1933.json
# Data has been saved to Acts No. 4093, November 29, 1933.json
# Data has been saved to Acts No. 4090, November 29, 1933.json
# Data has been saved to Acts No. 4091, November 29, 1933.json
# Data has been saved to Acts No. 4092, November 29, 1933.json
# Data has been saved to Act No. 4088, November 29, 1933.json
# Data has been saved to Acts No. 4089, November 29, 1933.json
# Data has been saved to Acts No. 4087, November 29, 1933.json
# Data has been saved to Acts No. 4086, November 29, 1933.json
# Data has been saved to Acts No. 4079, November 29, 1933.json
# Data has been saved to Acts No. 4083, November 29, 1933.json
# Data has been saved to Acts No. 4084, November 29, 1933.json
# Data has been saved to Acts No. 4085, November 29, 1933.json
# Data has been saved to Acts No. 4082, November 29, 1933.json
# Data has been saved to Acts No. 4081, November 29, 1933.json
# Data has been saved to Act No. 4080, November 29, 1933.json
# Data has been saved to Acts No. 4078, November 08, 1933.json
# Data has been saved to Acts No. 4123, December 09, 1933.json
# Data has been saved to Acts No. 4122, December 09, 1933.json
# Data has been saved to Acts No. 4120, December 08, 1933.json
# Data has been saved to Acts No. 4121, December 08, 1933.json
# Data has been saved to Acts No. 4119, December 08, 1933.json
# Data has been saved to Acts No. 4118, December 07, 1933.json
# Data has been saved to Acts No. 4117, December 07, 1933.json
# Data has been saved to Acts No. 4115, December 07, 1933.json
# Data has been saved to Acts No. 4116, December 07, 1933.json
# Data has been saved to Acts No. 4113, December 07, 1933.json
# Data has been saved to Acts No. 4114, December 07, 1933.json
# Data has been saved to Acts No. 4112, December 07, 1933.json
# Data has been saved to Acts No. 4111, December 06, 1933.json
# Data has been saved to Acts No. 4110, December 06, 1933.json
# Data has been saved to Acts No. 4109, December 06, 1933.json
# Data has been saved to Acts No. 4108, December 06, 1933.json
# Data has been saved to Acts No. 4107, December 06, 1933.json
# Data has been saved to Acts No. 4106, December 05, 1933.json
# Data has been saved to Acts No. 4104, December 05, 1933.json
# Data has been saved to Acts No. 4105, December 05, 1933.json
# Data has been saved to Acts No. 4103, December 05, 1933.json
# Data has been saved to Acts No. 4102, December 05, 1933.json
# Data has been saved to Acts No. 4101, December 01, 1933.json
# Data has been saved to Act No. 3914, January 20, 1932.json
# Data has been saved to Act No. 3915, February 01, 1932.json
# Data has been saved to Act No. 3917, March 16, 1932.json
# Data has been saved to Act No. 3916, March 11, 1932.json
# Data has been saved to Act No. 3918, April 08, 1932.json
# Data has been saved to Act No. 3919, July 30, 1932.json
# Data has been saved to Act No. 3920, August 08, 1932.json
# Data has been saved to Act No. 3922, September 12, 1932.json
# Data has been saved to Act No. 3921, September 06, 1932.json
# Data has been saved to Act No. 3925, October 15, 1932.json
# Data has been saved to Act No. 3924, October 05, 1932.json
# Data has been saved to Act No. 3923, October 04, 1932.json
# Data has been saved to Act No. 3937, November 29, 1932.json
# Data has been saved to Act No. 3938, November 29, 1932.json
# Data has been saved to Act No. 3936, November 29, 1932.json
# Data has been saved to Act No. 3945, November 29, 1932.json
# Data has been saved to Act No. 3941, November 29, 1932.json
# Data has been saved to Act No. 3942, November 29, 1932.json
# Data has been saved to Act No. 3943, November 29, 1932.json
# Data has been saved to Act No. 3944, November 29, 1932.json
# Data has been saved to Act No. 3940, November 29, 1932.json
# Data has been saved to Act No. 3939, November 29, 1932.json
# Data has been saved to Act No. 3934, November 29, 1932.json
# Data has been saved to Act No. 3935, November 29, 1932.json
# Data has been saved to Act No. 3933, November 29, 1932.json
# Data has been saved to Act No. 3932, November 29, 1932.json
# Data has been saved to Act No. 3931, November 28, 1932.json
# Data has been saved to Act No. 3929, November 28, 1932.json
# Data has been saved to Act No. 3930, November 28, 1932.json
# Data has been saved to Act No. 3927, November 28, 1932.json
# Data has been saved to Act No. 3928, November 28, 1932.json
# Data has been saved to Act No. 3926, November 07, 1932.json
# Data has been saved to Acts No. 4038, December 19, 1932.json
# Data has been saved to Acts No. 4034, December 17, 1932.json
# Data has been saved to Acts No. 4036, December 17, 1932.json
# Data has been saved to Acts No. 4035, December 17, 1932.json
# Data has been saved to Act No. 4037, December 17, 1932.json
# Data has been saved to Acts No. 4033, December 09, 1932.json
# Data has been saved to Act No. 4032, December 09, 1932.json
# Data has been saved to Acts No. 4031, December 08, 1932.json
# Data has been saved to Acts No. 4030, December 08, 1932.json
# Data has been saved to Acts No. 4027, December 08, 1932.json
# Data has been saved to Acts No. 4028, December 08, 1932.json
# Data has been saved to Acts No. 4029, December 08, 1932.json
# Data has been saved to Acts No. 4024, December 08, 1932.json
# Data has been saved to Acts No. 4025, December 08, 1932.json
# Data has been saved to Acts No. 4026, December 08, 1932.json
# Data has been saved to Acts No. 4023, December 08, 1932.json
# Data has been saved to Acts No. 4022, December 08, 1932.json
# Data has been saved to Acts No. 4021, December 08, 1932.json
# Data has been saved to Acts No. 4019, December 07, 1932.json
# Data has been saved to Acts No. 4018, December 07, 1932.json
# Data has been saved to Acts No. 4020, December 07, 1932.json
# Data has been saved to Acts No. 4017, December 07, 1932.json
# Data has been saved to Acts No. 4016, December 07, 1932.json
# Data has been saved to Acts No. 4015, December 07, 1932.json
# Data has been saved to Acts No. 4014, December 06, 1932.json
# Data has been saved to Acts No. 4013, December 06, 1932.json
# Data has been saved to Acts No. 4010, December 05, 1932.json
# Data has been saved to Acts No. 4011, December 05, 1932.json
# Data has been saved to Acts No. 4012, December 05, 1932.json
# Data has been saved to Acts No. 4009, December 05, 1932.json
# Data has been saved to Acts No. 4004, December 05, 1932.json
# Data has been saved to Acts No. 4005, December 05, 1932.json
# Data has been saved to Acts No. 4006, December 05, 1932.json
# Data has been saved to Acts No. 4008, December 05, 1932.json
# Data has been saved to Act No. 4000, December 05, 1932.json
# Data has been saved to Acts No. 4001, December 05, 1932.json
# Data has been saved to Acts No. 4002, December 05, 1932.json
# Data has been saved to Act No. 3999, December 05, 1932.json
# Data has been saved to Act No. 3998, December 05, 1932.json
# Data has been saved to Act No. 3995, December 05, 1932.json
# Data has been saved to Act No. 3997, December 05, 1932.json
# Data has been saved to Act No. 3996, December 05, 1932.json
# Data has been saved to Act No. 3993, December 05, 1932.json
# Data has been saved to Act No. 3994, December 05, 1932.json
# Data has been saved to Act No. 4003, December 05, 1932.json
# Data has been saved to Act No. 4007, December 05, 1932.json
# Data has been saved to Act No. 3992, December 03, 1932.json
# Data has been saved to Act No. 3988, December 03, 1932.json
# Data has been saved to Act No. 3990, December 03, 1932.json
# Data has been saved to Act No. 3987, December 03, 1932.json
# Data has been saved to Act No. 3989, December 03, 1932.json
# Data has been saved to Act No. 3991, December 03, 1932.json
# Data has been saved to Act No. 3986, December 03, 1932.json
# Data has been saved to Act No. 3985, December 03, 1932.json
# Data has been saved to Act No. 3984, December 03, 1932.json
# Data has been saved to Act No. 3983, December 03, 1932.json
# Data has been saved to Act No. 3982, December 03, 1932.json
# Data has been saved to Act No. 3981, December 03, 1932.json
# Data has been saved to Act No. 3980, December 03, 1932.json
# Data has been saved to Act No. 3979, December 03, 1932.json
# Data has been saved to Act No. 3978, December 03, 1932.json
# Data has been saved to Act No. 3977, December 03, 1932.json
# Data has been saved to Act No. 3976, December 03, 1932.json
# Data has been saved to Act No. 3974, December 03, 1932.json
# Data has been saved to Act No. 3975, December 03, 1932.json
# Data has been saved to Act No. 3973, December 03, 1932.json
# Data has been saved to Act No. 3957, December 02, 1932.json
# Data has been saved to Act No. 3971, December 02, 1932.json
# Data has been saved to Act No. 3972, December 02, 1932.json
# Data has been saved to Act No. 3969, December 02, 1932.json
# Data has been saved to Act No. 3970, December 02, 1932.json
# Data has been saved to Act No. 3968, December 02, 1932.json
# Data has been saved to Act No. 3967, December 02, 1932.json
# Data has been saved to Act No. 3965, December 02, 1932.json
# Data has been saved to Act No. 3966, December 02, 1932.json
# Data has been saved to Act Nos. 3963, December 02, 1932.json
# Data has been saved to Act No. 3964, December 02, 1932.json
# Data has been saved to Act No. 3962, December 02, 1932.json
# Data has been saved to Act No. 3961, December 02, 1932.json
# Data has been saved to Act No. 3959, December 02, 1932.json
# Data has been saved to Act No. 3960, December 02, 1932.json
# Data has been saved to Act No. 3958, December 02, 1932.json
# Data has been saved to Act No. 3956, December 01, 1932.json
# Data has been saved to Act No. 3955, December 01, 1932.json
# Data has been saved to Act No. 3954, December 01, 1932.json
# Data has been saved to Act No. 3953, December 01, 1932.json
# Data has been saved to Act No. 3952, December 01, 1932.json
# Data has been saved to Act No. 3946, December 01, 1932.json
# Data has been saved to Act No. 3947, December 01, 1932.json
# Data has been saved to Act No. 3949, December 01, 1932.json
# Data has been saved to Act No. 3950, December 01, 1932.json
# Data has been saved to Act No. 3951, December 01, 1932.json
# Data has been saved to Act No. 3948, December 01, 1932.json
# Data has been saved to Act No. 3818, January 22, 1931.json
# Data has been saved to Act No. 3822, February 25, 1931.json
# Data has been saved to Act No. 3821, February 24, 1931.json
# Data has been saved to Act No. 3819, February 11, 1931.json
# Data has been saved to Act No. 3820, February 11, 1931.json
# Data has been saved to Act No. 3823, August 11, 1931.json
# Data has been saved to Act No. 3832, October 30, 1931.json
# Data has been saved to Act No. 3830, October 30, 1931.json
# Data has been saved to Act No. 3831, October 30, 1931.json
# Data has been saved to Act No. 3829, October 30, 1931.json
# Data has been saved to Act No. 3827, October 28, 1931.json
# Data has been saved to Act No. 3828, October 28, 1931.json
# Data has been saved to Act No. 3825, October 08, 1931.json
# Data has been saved to Act No. 3826, October 08, 1931.json
# Data has been saved to Act No. 3824, October 05, 1931.json
# Data has been saved to Act No. 3913, November 28, 1931.json
# Data has been saved to Act No. 3911, November 20, 1931.json
# Data has been saved to Act No. 3908, November 20, 1931.json
# Data has been saved to Act No. 3907, November 20, 1931.json
# Data has been saved to Act No. 3909, November 20, 1931.json
# Data has been saved to Act No. 3910, November 20, 1931.json
# Data has been saved to Act No. 3906, November 20, 1931.json
# Data has been saved to Act No. 3912, November 20, 1931.json
# Data has been saved to Act No. 3905, November 18, 1931.json
# Data has been saved to Act No. 3904, November 18, 1931.json
# Data has been saved to Act No. 3903, November 17, 1931.json
# Data has been saved to Act No. 3901, November 17, 1931.json
# Data has been saved to Act No. 3902, November 17, 1931.json
# Data has been saved to Act No. 3896, November 16, 1931.json
# Data has been saved to Act No. 3895, November 16, 1931.json
# Data has been saved to Act No. 3894, November 16, 1931.json
# Data has been saved to Act No. 3898, November 16, 1931.json
# Data has been saved to Act No. 3899, November 16, 1931.json
# Data has been saved to Act No. 3900, November 16, 1931.json
# Data has been saved to Act No. 3897, November 16, 1931.json
# Data has been saved to Act No. 3893, November 16, 1931.json
# Data has been saved to Act No. 3892, November 16, 1931.json
# Data has been saved to Act No. 3891, November 16, 1931.json
# Data has been saved to Act No. 3889, November 16, 1931.json
# Data has been saved to Act No. 3890, November 16, 1931.json
# Data has been saved to Act No. 3888, November 16, 1931.json
# Data has been saved to Act No. 3887, November 14, 1931.json
# Data has been saved to Act No. 3886, November 14, 1931.json
# Data has been saved to Act No. 3885, November 14, 1931.json
# Data has been saved to Act No. 3884, November 14, 1931.json
# Data has been saved to Act No. 3882, November 14, 1931.json
# Data has been saved to Act No. 3883, November 14, 1931.json
# Data has been saved to Act No. 3881, November 14, 1931.json
# Data has been saved to Act No. 3880, November 14, 1931.json
# Data has been saved to Act No. 3870, November 13, 1931.json
# Data has been saved to Act No. 3879, November 13, 1931.json
# Data has been saved to Act No. 3876, November 13, 1931.json
# Data has been saved to Act No. 3877, November 13, 1931.json
# Data has been saved to Act No. 3878, November 13, 1931.json
# Data has been saved to Act No. 3872, November 13, 1931.json
# Data has been saved to Act No. 3873, November 13, 1931.json
# Data has been saved to Act No. 3874, November 13, 1931.json
# Data has been saved to Act No. 3875, November 13, 1931.json
# Data has been saved to Act No. 3871, November 13, 1931.json
# Data has been saved to Act No. 3866, November 13, 1931.json
# Data has been saved to Act No. 3867, November 13, 1931.json
# Data has been saved to Act No. 3868, November 13, 1931.json
# Data has been saved to Act No. 3869, November 13, 1931.json
# Data has been saved to Act No. 3864, November 13, 1931.json
# Data has been saved to Act No. 3865, November 13, 1931.json
# Data has been saved to Act No. 3863, November 13, 1931.json
# Data has been saved to Act No. 3862, November 13, 1931.json
# Data has been saved to Act No. 3858, November 13, 1931.json
# Data has been saved to Act No. 3859, November 13, 1931.json
# Data has been saved to Act No. 3860, November 13, 1931.json
# Data has been saved to Act No. 3861, November 13, 1931.json
# Data has been saved to Act No. 3857, November 12, 1931.json
# Data has been saved to Act No. 3851, November 12, 1931.json
# Data has been saved to Act No. 3852, November 12, 1931.json
# Data has been saved to Act No. 3854, November 12, 1931.json
# Data has been saved to Act No. 3855, November 12, 1931.json
# Data has been saved to Act No. 3856, November 12, 1931.json
# Data has been saved to Act No. 3853, November 12, 1931.json
# Data has been saved to Act No. 3846, November 11, 1931.json
# Data has been saved to Act No. 3847, November 11, 1931.json
# Data has been saved to Act No. 3848, November 11, 1931.json
# Data has been saved to Act No. 3849, November 11, 1931.json
# Data has been saved to Act No. 3850, November 11, 1931.json
# Data has been saved to Act No. 3845, November 10, 1931.json
# Data has been saved to Act No. 3840, November 09, 1931.json
# Data has been saved to Act No. 3841, November 09, 1931.json
# Data has been saved to Act No. 3842, November 09, 1931.json
# Data has been saved to Act No. 3843, November 09, 1931.json
# Data has been saved to Act No. 3844, November 09, 1931.json
# Data has been saved to Act No. 3838, November 07, 1931.json
# Data has been saved to Act No. 3839, November 07, 1931.json
# Data has been saved to Act No. 3837, November 06, 1931.json
# Data has been saved to Act No. 3835, November 06, 1931.json
# Data has been saved to Act No. 3836, November 06, 1931.json
# Data has been saved to Act No. 3833, November 05, 1931.json
# Data has been saved to Act No. 3834, November 05, 1931.json
# Data has been saved to Act No. 3671, February 08, 1930.json
# Data has been saved to Act No. 3608, February 08, 1930.json
# Data has been saved to Act No. 3672, February 07, 1930.json
# Data has been saved to Act No. 3674, June 30, 1930.json
# Data has been saved to Act No. 3673, June 27, 1930.json
# Data has been saved to Act No. 3675, July 25, 1930.json
# Data has been saved to Act No. 3677, August 09, 1930.json
# Data has been saved to Act No. 3676, August 02, 1930.json
# Data has been saved to Act No. 3679, September 08, 1930.json
# Data has been saved to Act No. 3678, September 03, 1930.json
# Data has been saved to Act No. 3682, October 29, 1930.json
# Data has been saved to Act No. 3680, October 16, 1930.json
# Data has been saved to Act No. 3681, October 16, 1930.json
# Data has been saved to Act No. 3785, November 29, 1930.json
# Data has been saved to Act No. 3784, November 29, 1930.json
# Data has been saved to Act No. 3783, November 28, 1930.json
# Data has been saved to Act No. 3781, November 28, 1930.json
# Data has been saved to Act No. 3782, November 28, 1930.json
# Data has been saved to Act No. 3780, November 28, 1930.json
# Data has been saved to Act No. 3777, November 28, 1930.json
# Data has been saved to Act No. 3778, November 28, 1930.json
# Data has been saved to Act No. 3779, November 28, 1930.json
# Data has been saved to Act No. 3776, November 28, 1930.json
# Data has been saved to Act No. 3774, November 28, 1930.json
# Data has been saved to Act No. 3775, November 28, 1930.json
# Data has been saved to Act No. 3773, November 28, 1930.json
# Data has been saved to Act No. 3772, November 28, 1930.json
# Data has been saved to Act No. 3768, November 28, 1930.json
# Data has been saved to Act No. 3769, November 28, 1930.json
# Data has been saved to Act No. 3770, November 28, 1930.json
# Data has been saved to Act No. 3771, November 28, 1930.json
# Data has been saved to Act No. 3695, November 27, 1930.json
# Data has been saved to Act No. 3767, November 26, 1930.json
# Data has been saved to Act No. 3766, November 26, 1930.json
# Data has been saved to Act No. 3765, November 26, 1930.json
# Data has been saved to Act No. 3764, November 26, 1930.json
# Data has been saved to Act No. 3763, November 26, 1930.json
# Data has been saved to Act No. 3762, November 26, 1930.json
# Data has been saved to Act No. 3761, November 26, 1930.json
# Data has been saved to Act No. 3760, November 26, 1930.json
# Data has been saved to Act No. 3759, November 26, 1930.json
# Data has been saved to Act No. 3757, November 26, 1930.json
# Data has been saved to Act No. 3758, November 26, 1930.json
# Data has been saved to Act No. 3756, November 26, 1930.json
# Data has been saved to Act No. 3755, November 26, 1930.json
# Data has been saved to Act No. 3754, November 26, 1930.json
# Data has been saved to Act No. 3753, November 26, 1930.json
# Data has been saved to Act No. 3751, November 26, 1930.json
# Data has been saved to Act No. 3752, November 26, 1930.json
# Data has been saved to Act No. 3750, November 26, 1930.json
# Data has been saved to Act No. 3749, November 24, 1930.json
# Data has been saved to Act No. 3747, November 24, 1930.json
# Data has been saved to Act No. 3748, November 24, 1930.json
# Data has been saved to Act No. 3746, November 24, 1930.json
# Data has been saved to Act No. 3742, November 24, 1930.json
# Data has been saved to Act No. 3743, November 24, 1930.json
# Data has been saved to Act No. 3744, November 24, 1930.json
# Data has been saved to Act No. 3745, November 24, 1930.json
# Data has been saved to Act No. 3739, November 22, 1930.json
# Data has been saved to Act No. 3740, November 22, 1930.json
# Data has been saved to Act No. 3741, November 22, 1930.json
# Data has been saved to Act No. 3737, November 22, 1930.json
# Data has been saved to Act No. 3738, November 22, 1930.json
# Data has been saved to Act No. 3733, November 22, 1930.json
# Data has been saved to Act No. 3734, November 22, 1930.json
# Data has been saved to Act No. 3735, November 22, 1930.json
# Data has been saved to Act No. 3736, November 22, 1930.json
# Data has been saved to Act No. 3728, November 21, 1930.json
# Data has been saved to Act No. 3729, November 21, 1930.json
# Data has been saved to Act No. 3730, November 21, 1930.json
# Data has been saved to Act No. 3731, November 21, 1930.json
# Data has been saved to Act No. 3732, November 21, 1930.json
# Data has been saved to Act No. 3725, November 21, 1930.json
# Data has been saved to Act No. 3726, November 21, 1930.json
# Data has been saved to Act No. 3727, November 21, 1930.json
# Data has been saved to Act No. 3723, November 21, 1930.json
# Data has been saved to Act No. 3724, November 21, 1930.json
# Data has been saved to Act No. 3722, November 21, 1930.json
# Data has been saved to Act No. 3721, November 21, 1930.json
# Data has been saved to Act No. 3720, November 21, 1930.json
# Data has been saved to Act No. 3719, November 21, 1930.json
# Data has been saved to Act No. 3716, November 20, 1930.json
# Data has been saved to Act No. 3717, November 20, 1930.json
# Data has been saved to Act No. 3718, November 20, 1930.json
# Data has been saved to Act No. 3715, November 20, 1930.json
# Data has been saved to Act No. 3714, November 20, 1930.json
# Data has been saved to Act No. 3704, November 20, 1930.json
# Data has been saved to Act No. 3705, November 20, 1930.json
# Data has been saved to Act No. 3697, November 20, 1930.json
# Data has been saved to Act No. 3698, November 20, 1930.json
# Data has been saved to Act No. 3699, November 20, 1930.json
# Data has been saved to Act No. 3700, November 20, 1930.json
# Data has been saved to Act No. 3701, November 20, 1930.json
# Data has been saved to Act No. 3702, November 20, 1930.json
# Data has been saved to Act No. 3696, November 20, 1930.json
# Data has been saved to Act No. 3693, November 20, 1930.json
# Data has been saved to Act No. 3694, November 20, 1930.json
# Data has been saved to Act No. 3692, November 20, 1930.json
# Data has been saved to Act No. 3690, November 20, 1930.json
# Data has been saved to Act No. 3691, November 20, 1930.json
# Data has been saved to Act No. 3706, November 20, 1930.json
# Data has been saved to Act No. 3707, November 20, 1930.json
# Data has been saved to Act No. 3708, November 20, 1930.json
# Data has been saved to Act No. 3709, November 20, 1930.json
# Data has been saved to Act No. 3710, November 20, 1930.json
# Data has been saved to Act No. 3711, November 20, 1930.json
# Data has been saved to Act No. 3712, November 20, 1930.json
# Data has been saved to Act No. 3713, November 20, 1930.json
# Data has been saved to Act No. 3703, November 20, 1930.json
# Data has been saved to Act No. 3689, November 11, 1930.json
# Data has been saved to Act No. 3687, November 07, 1930.json
# Data has been saved to Act No. 3688, November 07, 1930.json
# Data has been saved to Act No. 3686, November 06, 1930.json
# Data has been saved to Act No. 3685, November 06, 1930.json
# Data has been saved to Act No. 3684, November 05, 1930.json
# Data has been saved to Act No. 3683, November 03, 1930.json
# Data has been saved to Act No. 3817, December 09, 1930.json
# Data has been saved to Act No. 3816, December 08, 1930.json
# Data has been saved to Act No. 3815, December 08, 1930.json
# Data has been saved to Act No. 3814, December 08, 1930.json
# Data has been saved to Act No. 3812, December 08, 1930.json
# Data has been saved to Act No. 3813, December 08, 1930.json
# Data has been saved to Act No. 3810, December 06, 1930.json
# Data has been saved to Act No. 3811, December 06, 1930.json
# Data has been saved to Act No. 3808, December 06, 1930.json
# Data has been saved to Act No. 3809, December 06, 1930.json
# Data has been saved to Act No. 3805, December 05, 1930.json
# Data has been saved to Act No. 3806, December 05, 1930.json
# Data has been saved to Act No. 3807, December 05, 1930.json
# Data has been saved to Act No. 3804, December 05, 1930.json
# Data has been saved to Act No. 3803, December 05, 1930.json
# Data has been saved to Act No. 3802, December 04, 1930.json
# Data has been saved to Act No. 3801, December 04, 1930.json
# Data has been saved to Act No. 3799, December 04, 1930.json
# Data has been saved to Act No. 3800, December 04, 1930.json
# Data has been saved to Act No. 3798, December 04, 1930.json
# Data has been saved to Act No. 3797, December 04, 1930.json
# Data has been saved to Act No. 3796, December 03, 1930.json
# Data has been saved to Act No. 3795, December 03, 1930.json
# Data has been saved to Act No. 3793, December 02, 1930.json
# Data has been saved to Act No. 3794, December 02, 1930.json
# Data has been saved to Act No. 3791, December 02, 1930.json
# Data has been saved to Act No. 3792, December 02, 1930.json
# Data has been saved to Act No. 3789, December 02, 1930.json
# Data has been saved to Act No. 3790, December 02, 1930.json
# Data has been saved to Act No. 3788, December 02, 1930.json
# Data has been saved to Act No. 3786, December 02, 1930.json
# Data has been saved to Act No. 3787, December 02, 1930.json
# Data has been saved to Act No. 3517, January 30, 1929.json
# Data has been saved to Act No. 3516, January 08, 1929.json
# Data has been saved to Act No. 3515, January 08, 1929.json
# Data has been saved to Act No. 3524, February 24, 1929.json
# Data has been saved to Act No. 3523, February 21, 1929.json
# Data has been saved to Act No. 3525, February 21, 1929.json
# Data has been saved to Act No. 3526, February 21, 1929.json
# Data has been saved to Act No. 3527, February 21, 1929.json
# Data has been saved to Act No. 3528, February 21, 1929.json
# Data has been saved to Act No. 3519, February 20, 1929.json
# Data has been saved to Act No. 3520, February 20, 1929.json
# Data has been saved to Act No. 3521, February 20, 1929.json
# Data has been saved to Act No. 3522, February 20, 1929.json
# Data has been saved to Act No. 3518, March 01, 1929.json
# Data has been saved to Act No. 3529, August 09, 1929.json
# Data has been saved to Act No. 3530, August 09, 1929.json
# Data has been saved to Act No. 3531, September 28, 1929.json
# Data has been saved to Act No. 3535, October 31, 1929.json
# Data has been saved to Act No. 3534, October 29, 1929.json
# Data has been saved to Act No. 3533, October 24, 1929.json
# Data has been saved to Act No. 3532, October 24, 1929.json
# Data has been saved to Act No. 3602, November 30, 1929.json
# Data has been saved to Act No. 3601, November 29, 1929.json
# Data has been saved to Act No. 3599, November 29, 1929.json
# Data has been saved to Act No. 3597, November 29, 1929.json
# Data has been saved to Act No. 3596, November 29, 1929.json
# Data has been saved to Act No. 3595, November 29, 1929.json
# Data has been saved to Act No. 3594, November 29, 1929.json
# Data has been saved to Act No. 3593, November 29, 1929.json
# Data has been saved to Act No. 3592, November 29, 1929.json
# Data has been saved to Act No. 3591, November 29, 1929.json
# Data has been saved to Act No. 3590, November 29, 1929.json
# Data has been saved to Act No. 3600, November 29, 1929.json
# Data has been saved to Act No. 3598, November 29, 1929.json
# Data has been saved to Act No. 3589, November 27, 1929.json
# Data has been saved to Act No. 3587, November 27, 1929.json
# Data has been saved to Act No. 3584, November 27, 1929.json
# Data has been saved to Act No. 3586, November 27, 1929.json
# Data has been saved to Act No. 3585, November 27, 1929.json
# Data has been saved to Act No. 3581, November 27, 1929.json
# Data has been saved to Act No. 3580, November 27, 1929.json
# Data has been saved to Act No. 3579, November 27, 1929.json
# Data has been saved to Act No. 3578, November 27, 1929.json
# Data has been saved to Act No. 3577, November 27, 1929.json
# Data has been saved to Act No. 3583, November 27, 1929.json
# Data has been saved to Act No. 3582, November 27, 1929.json
# Data has been saved to Act No. 3576, November 27, 1929.json
# Data has been saved to Act No. 3588, November 27, 1929.json
# Data has been saved to Act No. 3558, November 26, 1929.json
# Data has been saved to Act No. 3559, November 26, 1929.json
# Data has been saved to Act No. 3560, November 26, 1929.json
# Data has been saved to Act No. 3561, November 26, 1929.json
# Data has been saved to Act No. 3562, November 26, 1929.json
# Data has been saved to Act No. 3563, November 26, 1929.json
# Data has been saved to Act No. 3564, November 26, 1929.json
# Data has been saved to Act No. 3565, November 26, 1929.json
# Data has been saved to Act No. 3566, November 26, 1929.json
# Data has been saved to Act No. 3567, November 26, 1929.json
# Data has been saved to Act No. 3575, November 26, 1929.json
# Data has been saved to Act No. 3574, November 26, 1929.json
# Data has been saved to Act No. 3573, November 26, 1929.json
# Data has been saved to Act No. 3572, November 26, 1929.json
# Data has been saved to Act No. 3571, November 26, 1929.json
# Data has been saved to Act No. 3570, November 26, 1929.json
# Data has been saved to Act No. 3569, November 26, 1929.json
# Data has been saved to Act No. 3568, November 26, 1929.json
# Data has been saved to Act No. 3556, November 25, 1929.json
# Data has been saved to Act No. 3557, November 25, 1929.json
# Data has been saved to Act No. 3549, November 23, 1929.json
# Data has been saved to Act No. 3550, November 23, 1929.json
# Data has been saved to Act No. 3551, November 23, 1929.json
# Data has been saved to Act No. 3552, November 23, 1929.json
# Data has been saved to Act No. 3553, November 23, 1929.json
# Data has been saved to Act No. 3554, November 23, 1929.json
# Data has been saved to Act No. 3555, November 23, 1929.json
# Data has been saved to Act No. 3539, November 22, 1929.json
# Data has been saved to Act No. 3540, November 22, 1929.json
# Data has been saved to Act No. 3541, November 22, 1929.json
# Data has been saved to Act No. 3542, November 22, 1929.json
# Data has been saved to Act No. 3543, November 22, 1929.json
# Data has been saved to Act No. 3544, November 22, 1929.json
# Data has been saved to Act No. 3545, November 22, 1929.json
# Data has been saved to Act No. 3546, November 22, 1929.json
# Data has been saved to Act No. 3547, November 22, 1929.json
# Data has been saved to Act No. 3548, November 22, 1929.json
# Data has been saved to Act No. 3538, November 13, 1929.json
# Data has been saved to Act No. 3537, November 02, 1929.json
# Data has been saved to Act No. 3536, November 01, 1929.json
# Data has been saved to Act No. 3669, December 08, 1929.json
# Data has been saved to Act No. 3668, December 08, 1929.json
# Data has been saved to Act No. 3667, December 08, 1929.json
# Data has been saved to Act No. 3670, December 08, 1929.json
# Data has been saved to Act No. 3658, December 07, 1929.json
# Data has been saved to Act No. 3666, December 07, 1929.json
# Data has been saved to Act No. 3665, December 07, 1929.json
# Data has been saved to Act No. 3664, December 07, 1929.json
# Data has been saved to Act No. 3663, December 07, 1929.json
# Data has been saved to Act No. 3662, December 07, 1929.json
# Data has been saved to Act No. 3661, December 07, 1929.json
# Data has been saved to Act No. 3660, December 07, 1929.json
# Data has been saved to Act No. 3659, December 07, 1929.json
# Data has been saved to Act No. 3657, December 07, 1929.json
# Data has been saved to Act No. 3656, December 07, 1929.json
# Data has been saved to Act No. 3655, December 07, 1929.json
# Data has been saved to Act No. 3654, December 07, 1929.json
# Data has been saved to Act No. 3653, December 07, 1929.json
# Data has been saved to Act No. 3652, December 07, 1929.json
# Data has been saved to Act No. 3651, December 07, 1929.json
# Data has been saved to Act No. 3650, December 07, 1929.json
# Data has been saved to Act No. 3649, December 07, 1929.json
# Data has been saved to Act No. 3648, December 07, 1929.json
# Data has been saved to Act No. 3647, December 07, 1929.json
# Data has been saved to Act No. 3646, December 07, 1929.json
# Data has been saved to Act No. 3645, December 07, 1929.json
# Data has been saved to Act No. 3644, December 07, 1929.json
# Data has been saved to Act No. 3642, December 07, 1929.json
# Data has been saved to Act No. 3641, December 07, 1929.json
# Data has been saved to Act No. 3643, December 07, 1929.json
# Data has been saved to Act No. 3640, December 07, 1929.json
# Data has been saved to Act No. 3639, December 07, 1929.json
# Data has been saved to Act No. 3636, December 07, 1929.json
# Data has been saved to Act No. 3635, December 07, 1929.json
# Data has been saved to Act No. 3637, December 07, 1929.json
# Data has been saved to Act No. 3638, December 07, 1929.json
# Data has been saved to Act No. 3633, December 06, 1929.json
# Data has been saved to Act No. 3632, December 06, 1929.json
# Data has been saved to Act No. 3631, December 06, 1929.json
# Data has been saved to Act No. 3630, December 06, 1929.json
# Data has been saved to Act No. 3629, December 06, 1929.json
# Data has been saved to Act No. 3634, December 06, 1929.json
# Data has been saved to Act No. 3628, December 05, 1929.json
# Data has been saved to Act No. 3627, December 05, 1929.json
# Data has been saved to Act No. 3626, December 05, 1929.json
# Data has been saved to Act No. 3625, December 05, 1929.json
# Data has been saved to Act No. 3624, December 05, 1929.json
# Data has been saved to Act No. 3623, December 05, 1929.json
# Data has been saved to Act No. 3622, December 05, 1929.json
# Data has been saved to Act No. 3621, December 05, 1929.json
# Data has been saved to Act No. 3620, December 05, 1929.json
# Data has been saved to Act No. 3619, December 05, 1929.json
# Data has been saved to Act No. 3618, December 05, 1929.json
# Data has been saved to Act No. 3617, December 05, 1929.json
# Data has been saved to Act No. 3616, December 04, 1929.json
# Data has been saved to Act No. 3615, December 04, 1929.json
# Data has been saved to Act No. 3614, December 04, 1929.json
# Data has been saved to Act No. 3613, December 04, 1929.json
# Data has been saved to Act No. 3609, December 03, 1929.json
# Data has been saved to Act No. 3610, December 03, 1929.json
# Data has been saved to Act No. 3612, December 03, 1929.json
# Data has been saved to Act No. 3611, December 03, 1929.json
# Data has been saved to Act No. 3606, December 02, 1929.json
# Data has been saved to Act No. 3603, December 02, 1929.json
# Data has been saved to Act No. 3604, December 02, 1929.json
# Data has been saved to Act No. 3605, December 02, 1929.json
# Data has been saved to Act No. 3607, December 02, 1929.json
# Data has been saved to Act No. 3430, January 12, 1928.json
# Data has been saved to Act No. 3429, January 04, 1928.json
# Data has been saved to Act No. 3431, August 28, 1928.json
# Data has been saved to Act No. 3433, October 25, 1928.json
# Data has been saved to Act No. 3432, October 06, 1928.json
# Data has been saved to Act No. 3444, November 30, 1928.json
# Data has been saved to Act No. 3445, November 30, 1928.json
# Data has been saved to Act No. 3446, November 30, 1928.json
# Data has been saved to Act No. 3447, November 30, 1928.json
# Data has been saved to Act No. 3448, November 30, 1928.json
# Data has been saved to Act No. 3449, November 30, 1928.json
# Data has been saved to Act No. 3434, November 28, 1928.json
# Data has been saved to Act No. 3438, November 28, 1928.json
# Data has been saved to Act No. 3435, November 28, 1928.json
# Data has been saved to Act No. 3436, November 28, 1928.json
# Data has been saved to Act No. 3437, November 28, 1928.json
# Data has been saved to Act No. 3439, November 28, 1928.json
# Data has been saved to Act No. 3440, November 28, 1928.json
# Data has been saved to Act No. 3441, November 28, 1928.json
# Data has been saved to Act No. 3442, November 28, 1928.json
# Data has been saved to Act No. 3443, November 28, 1928.json
# Data has been saved to Act No. 3474, November 07, 1928.json
# Data has been saved to Act No. 3514, December 28, 1928.json
# Data has been saved to Act No. 3501, December 08, 1928.json
# Data has been saved to Act No. 3510, December 08, 1928.json
# Data has been saved to Act No. 3507, December 08, 1928.json
# Data has been saved to Act No. 3503, December 08, 1928.json
# Data has been saved to Act No. 3504, December 08, 1928.json
# Data has been saved to Act No. 3485, December 08, 1928.json
# Data has been saved to Act No. 3486, December 08, 1928.json
# Data has been saved to Act No. 3487, December 08, 1928.json
# Data has been saved to Act No. 3488, December 08, 1928.json
# Data has been saved to Act No. 3489, December 08, 1928.json
# Data has been saved to Act No. 3491, December 08, 1928.json
# Data has been saved to Act No. 3490, December 08, 1928.json
# Data has been saved to Act No. 3492, December 08, 1928.json
# Data has been saved to Act No. 3493, December 08, 1928.json
# Data has been saved to Act No. 3494, December 08, 1928.json
# ...
# Data has been saved to Act No. 3368, December 03, 1927.json
# Data has been saved to Act No. 3369, December 03, 1927.json
# Data has been saved to Act No. 3370, December 03, 1927.json
# Data has been saved to Act No. 3371, December 03, 1927.json
# Data has been saved to Act No. 3372, December 03, 1927.json
# Data has been saved to Act No. 3373, December 03, 1927.json
# Data has been saved to Act No. 3374, December 03, 1927.json
# Data has been saved to Act No. 3375, December 03, 1927.json
# Data has been saved to Act No. 3376, December 03, 1927.json
# Data has been saved to Act No. 3376, December 03, 1927.json
# Data has been saved to Act No. 3377, December 03, 1927.json
# Data has been saved to Act No. 3378, December 03, 1927.json
# Data has been saved to Act No. 3379, December 03, 1927.json
# Data has been saved to Act No. 3380, December 03, 1927.json
# Data has been saved to Act No. 3381, December 03, 1927.json
# Data has been saved to Act No. 3382, December 03, 1927.json
# Data has been saved to Act No. 3383, December 03, 1927.json
# Data has been saved to Act No. 3384, December 03, 1927.json
# Data has been saved to Act No. 3385, December 03, 1927.json
# Data has been saved to Act No. 3386, December 03, 1927.json
# Data has been saved to Act No. 3388, December 03, 1927.json
# Data has been saved to Act No. 3389, December 03, 1927.json
# Data has been saved to Act No. 3355, December 02, 1927.json
# Data has been saved to Act No. 3269, July 30, 1926.json
# Data has been saved to Act No. 3270, August 11, 1926.json
# Data has been saved to Act No. 3272, October 15, 1926.json
# Data has been saved to Act No. 3271, October 06, 1926.json
# Data has been saved to Act No. 3282, November 30, 1926.json
# Data has been saved to Act No. 3281, November 30, 1926.json
# Data has been saved to Act No. 3280, November 30, 1926.json
# Data has been saved to Act No. 3279, November 30, 1926.json
# Data has been saved to Act No. 3278, November 30, 1926.json
# Data has been saved to Act No. 3277, November 19, 1926.json
# Data has been saved to Act No. 3276, November 19, 1926.json
# Data has been saved to Act No. 3274, November 19, 1926.json
# Data has been saved to Act No. 3275, November 19, 1926.json
# Data has been saved to Act No. 3273, November 12, 1926.json
# Data has been saved to Act No. 3345, December 09, 1926.json
# Data has been saved to Act No. 3342, December 08, 1926.json
# Data has been saved to Act No. 3343, December 08, 1926.json
# Data has been saved to Act No. 3344, December 08, 1926.json
# Data has been saved to Act No. 3339, December 07, 1926.json
# Data has been saved to Act No. 3338, December 07, 1926.json
# Data has been saved to Act No. 3335, December 07, 1926.json
# Data has been saved to Act No. 3337, December 07, 1926.json
# Data has been saved to Act No. 3336, December 07, 1926.json
# Data has been saved to Act No. 3331, December 07, 1926.json
# Data has been saved to Act No. 3332, December 07, 1926.json
# Data has been saved to Act No. 3333, December 07, 1926.json
# Data has been saved to Act No. 3334, December 07, 1926.json
# Data has been saved to Act No. 3330, December 07, 1926.json
# Data has been saved to Act No. 3329, December 07, 1926.json
# Data has been saved to Act No. 3328, December 07, 1926.json
# Data has been saved to Act No. 3340, December 07, 1926.json
# Data has been saved to Act No. 3341, December 07, 1926.json
# Data has been saved to Act No. 3327, December 06, 1926.json
# Data has been saved to Act No. 3326, December 04, 1926.json
# Data has been saved to Act No. 3325, December 04, 1926.json
# Data has been saved to Act No. 3324, December 04, 1926.json
# Data has been saved to Act No. 3323, December 04, 1926.json
# Data has been saved to Act No. 3322, December 04, 1926.json
# Data has been saved to Act No. 3321, December 04, 1926.json
# Data has been saved to Act No. 3320, December 04, 1926.json
# Data has been saved to Act No. 3319, December 04, 1926.json
# Data has been saved to Act No. 3318, December 04, 1926.json
# Data has been saved to Act No. 3317, December 04, 1926.json
# Data has been saved to Act No. 3316, December 04, 1926.json
# Data has been saved to Act No. 3315, December 03, 1926.json
# Data has been saved to Act No. 3314, December 03, 1926.json
# Data has been saved to Act No. 3313, December 03, 1926.json
# Data has been saved to Act No. 3312, December 02, 1926.json
# Data has been saved to Act No. 3311, December 02, 1926.json
# Data has been saved to Act No. 3310, December 02, 1926.json
# Data has been saved to Act No. 3309, December 02, 1926.json
# Data has been saved to Act No. 3308, December 02, 1926.json
# Data has been saved to Act No. 3300, December 02, 1926.json
# Data has been saved to Act No. 3301, December 02, 1926.json
# Data has been saved to Act No. 3298, December 02, 1926.json
# Data has been saved to Act No. 3299, December 02, 1926.json
# Data has been saved to Act No. 3303, December 02, 1926.json
# Data has been saved to Act No. 3304, December 02, 1926.json
# Data has been saved to Act No. 3305, December 02, 1926.json
# Data has been saved to Act No. 3306, December 02, 1926.json
# Data has been saved to Act No. 3307, December 02, 1926.json
# Data has been saved to Act No. 3302, December 02, 1926.json
# Data has been saved to Act No. 3297, December 02, 1926.json
# Data has been saved to Act No. 3296, December 02, 1926.json
# Data has been saved to Act No. 3294, December 02, 1926.json
# Data has been saved to Act No. 3295, December 02, 1926.json
# Data has been saved to Act No. 3292, December 02, 1926.json
# Data has been saved to Act No. 3293, December 02, 1926.json
# Data has been saved to Act No. 3291, December 02, 1926.json
# Data has been saved to Act No. 3290, December 02, 1926.json
# Data has been saved to Act No. 3285, December 01, 1926.json
# Data has been saved to Act No. 3286, December 01, 1926.json
# Data has been saved to Act No. 3287, December 01, 1926.json
# Data has been saved to Act No. 3288, December 01, 1926.json
# Data has been saved to Act No. 3289, December 01, 1926.json
# Data has been saved to Act No. 3284, December 01, 1926.json
# Data has been saved to Act No. 3220, January 19, 1925.json
# Data has been saved to Act No. 3219, January 19, 1925.json
# Data has been saved to Act No. 3218, January 12, 1925.json
# Data has been saved to Act No. 3217, January 01, 1925.json
# Data has been saved to Act No. 3221, August 14, 1925.json
# Data has been saved to Act No. 3222, September 16, 1925.json
# Data has been saved to Act No. 3234, October 23, 1925.json
# Data has been saved to Act No. 3224, October 23, 1925.json
# Data has been saved to Act No. 3223, October 19, 1925.json
# Data has been saved to Act No. 3245, November 28, 1925.json
# Data has been saved to Act No. 3244, November 28, 1925.json
# Data has been saved to Act No. 3240, November 27, 1925.json
# Data has been saved to Act No. 3241, November 27, 1925.json
# Data has been saved to Act No. 3242, November 27, 1925.json
# Data has been saved to Act No. 3243, November 27, 1925.json
# Data has been saved to Act No. 3239, November 27, 1925.json
# Data has been saved to Act No. 3234, November 27, 1925.json
# Data has been saved to Act No. 3235, November 27, 1925.json
# Data has been saved to Act No. 3236, November 27, 1925.json
# Data has been saved to Act No. 3237, November 27, 1925.json
# Data has been saved to Act No. 3238, November 27, 1925.json
# Data has been saved to Act No. 3231, November 27, 1925.json
# Data has been saved to Act No. 3232, November 27, 1925.json
# Data has been saved to Act No. 3233, November 27, 1925.json
# Data has been saved to Act No. 3229, November 14, 1925.json
# Data has been saved to Act No. 3230, November 14, 1925.json
# Data has been saved to Act No. 3228, November 12, 1925.json
# Data has been saved to Act No. 3227, November 06, 1925.json
# Data has been saved to Act No. 3225, November 02, 1925.json
# Data has been saved to Act No. 3226, November 02, 1925.json
# Data has been saved to Act No. 3249, December 25, 1925.json
# Data has been saved to Act No. 3268, December 09, 1925.json
# Data has been saved to Act No. 3258, December 09, 1925.json
# Data has been saved to Act No. 3267, December 08, 1925.json
# Data has been saved to Act No. 3262, December 07, 1925.json
# Data has been saved to Act No. 3266, December 07, 1925.json
# Data has been saved to Act No. 3265, December 07, 1925.json
# Data has been saved to Act No. 3264, December 07, 1925.json
# Data has been saved to Act No. 3263, December 07, 1925.json
# Data has been saved to Act No. 3260, December 07, 1925.json
# Data has been saved to Act No. 3261, December 07, 1925.json
# Data has been saved to Act No. 3259, December 05, 1925.json
# Data has been saved to Act No. 3256, December 03, 1925.json
# Data has been saved to Act No. 3257, December 03, 1925.json
# Data has been saved to Act No. 3254, December 03, 1925.json
# Data has been saved to Act No. 3255, December 03, 1925.json
# Data has been saved to Act No. 3253, December 03, 1925.json
# Data has been saved to Act No. 3252, December 01, 1925.json
# Data has been saved to Act No. 3251, December 01, 1925.json
# Data has been saved to Act No. 3250, December 01, 1925.json
# Data has been saved to Act No. 3248, December 01, 1925.json
# Data has been saved to Act No. 3247, December 01, 1925.json
# Data has been saved to Act No. 3246, December 01, 1925.json
# Data has been saved to Act No. 3125, February 28, 1924.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 97
#      94 #             time.sleep(5)  # Sleep for 5 seconds after each document scrape to avoid overwhelming the server
#      96 if __name__ == "__main__":
# ---> 97     main()
#
# Cell In[1], line 93, in main()
#      91 for doc_link in document_links:
#      92     full_doc_url = 'https://elibrary.judiciary.gov.ph' + doc_link if not doc_link.startswith('http') else doc_link
# ---> 93     scrape_and_save(full_doc_url, output_folder)
#
# Cell In[1], line 40, in scrape_and_save(url, output_folder)
#      38 for attempt in range(retries):
#      39     try:
# ---> 40         response = requests.get(url, headers=headers)
#      41         if response.status_code == 200:
#      42             break
#
# File D:\Python\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File D:\Python\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File D:\Python\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File D:\Python\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File D:\Python\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File D:\Python\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File D:\Python\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File D:\Python\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File D:\Python\lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#     365     tls_in_tls = False
#
# File D:\Python\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File D:\Python\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      67 except UnicodeError:
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#      74     sock = None
#
# File D:\Python\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     952 # We override this function since we want to translate the numeric family
#     953 # and socket type values to enum constants.
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#     957     addrlist.append((_intenum_converter(af, AddressFamily),
#     958                      _intenum_converter(socktype, SocketKind),
#     959                      proto, canonname, sa))
#
# KeyboardInterrupt:
